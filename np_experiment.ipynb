# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
path = Path('/Volumes/Seagate Portable Drive/2024-03-20_10-45-01_SC20_closedloop_pilot/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.ProbeA-AP/continuous.dat')

data = np.memmap(path, dtype='int16', mode='r')
print(data.shape)
# Out:
# (17343433728,)

# %%
sr = 30000

# %%
data = data.reshape(-1, 384).T
print(data.shape)
# Out:
# (384, 45165192)

# %%
data.shape[1] / 30000
# Out:
# 1505.5064

# %%
ch0 = data[0, :data.shape[1]//30000*30000]
ch0 = ch0.reshape(-1, 30000)
ch0.shape
# Out:
# (1505, 30000)

# %%
ch0_std = np.load('/Users/yefan/Desktop/rot2/rot2-project/ch0_std.npy')
print(ch0_std.shape)
# Out:
# (1505,)

# %%
plt.plot(ch0_std)

# %%
idx = 930
pad = 5
plt.plot(ch0_std[idx-pad:idx+pad])

# %%
ch0[idx-pad:idx+pad].reshape(-1).shape
# Out:
# (300000,)

# %%
plt.plot(ch0[idx-pad:idx+pad].reshape(-1))
