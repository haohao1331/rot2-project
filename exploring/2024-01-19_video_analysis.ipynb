# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
is_red_path = Path('/Users/yefan/Desktop/rot2/rot2-project/data/2024-01-19_video_analysis/is_red.npy')
is_red = np.load(is_red_path)
y_loc_path = Path('/Users/yefan/Desktop/rot2/rot2-project/data/2024-01-19_video_analysis/y_loc.npy')
y_loc = np.load(y_loc_path)

print(is_red.shape)
print(y_loc.shape)
# Out:
# (9032,)
# (9032,)

# %%
n_frames = is_red.shape[0]
plt.plot(((y_loc - np.mean(y_loc)) / np.std(y_loc)))
plt.plot(is_red)

# %%
y_loc_diff = np.diff(y_loc)
y_loc_diff = y_loc
start, end = 3000, 4000

plt.plot(((y_loc_diff - np.mean(y_loc_diff)) / np.std(y_loc_diff))[start:end])
plt.plot(is_red[start:end])
